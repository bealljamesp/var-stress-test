# %%
(var-stress-test) beall@JamesBSurface8:~/projects/var-stress-test$ python main.py
[Export Complete] Descriptive statistics saved to: data/raw/week10_descriptive_summary.csv

=================================================================
PORTFOLIO: 2008 Crisis - Concentrated Financials
HORIZON:   2007-01-01 to 2009-12-31
=================================================================
Confidence Level:            95.0%
  In-Sample Hist VaR:        6.30%  ($62,951.86)
  In-Sample Param VaR:       7.46%  ($74,600.35)
-----------------------------------------------------------------
ROLLING OUT-OF-SAMPLE BACKTEST (252-Day Window, 502 Out-of-Sample Days):
  1. Rolling Historical Simulation:
     - Breaches:             46 / 502 (9.16%)
     - Kupiec POF:           LR=14.861 (p=0.0001) -> REJECT H0
     - Christoffersen Indep: LR=0.469 (p=0.4933) -> ACCEPT H0
  2. Rolling Parametric (Normal):
     - Breaches:             44 / 502 (8.76%)
     - Kupiec POF:           LR=12.355 (p=0.0004) -> REJECT H0
     - Christoffersen Indep: LR=0.248 (p=0.6183) -> ACCEPT H0
  3. Dynamic EWMA (RiskMetrics lambda=0.94):
     - Breaches:             34 / 502 (6.77%)
     - Kupiec POF:           LR=3.005 (p=0.0830) -> ACCEPT H0
     - Christoffersen Indep: LR=1.053 (p=0.3048) -> ACCEPT H0
  4. Dynamic GJR-GARCH(1,1) (Asymmetric Leverage):
     - Breaches:             34 / 502 (6.77%)
     - Kupiec POF:           LR=3.005 (p=0.0830) -> ACCEPT H0
     - Christoffersen Indep: LR=1.207 (p=0.2720) -> ACCEPT H0
  5. Filtered Historical Simulation (FHS / GJR-GARCH Tail):
     - Breaches:             37 / 502 (7.37%)
     - Kupiec POF:           LR=5.215 (p=0.0224) -> REJECT H0
     - Christoffersen Indep: LR=0.030 (p=0.8631) -> ACCEPT H0
findfont: Failed to find font weight semibold, now using 700.
[+] Saved Backtest Diagnostics plot: /home/beall/projects/var-stress-test/data/plots/var_diagnostics_concentrated_financials.png

=================================================================
PORTFOLIO: 2008 Crisis - Multi-Asset Diverse
HORIZON:   2007-01-01 to 2009-12-31
=================================================================
Confidence Level:            95.0%
  In-Sample Hist VaR:        1.27%  ($12,675.09)
  In-Sample Param VaR:       1.42%  ($14,241.72)
-----------------------------------------------------------------
ROLLING OUT-OF-SAMPLE BACKTEST (252-Day Window, 502 Out-of-Sample Days):
  1. Rolling Historical Simulation:
     - Breaches:             29 / 502 (5.78%)
     - Kupiec POF:           LR=0.609 (p=0.4352) -> ACCEPT H0
     - Christoffersen Indep: LR=12.102 (p=0.0005) -> REJECT H0
  2. Rolling Parametric (Normal):
     - Breaches:             31 / 502 (6.18%)
     - Kupiec POF:           LR=1.363 (p=0.2431) -> ACCEPT H0
     - Christoffersen Indep: LR=7.091 (p=0.0077) -> REJECT H0
  3. Dynamic EWMA (RiskMetrics lambda=0.94):
     - Breaches:             26 / 502 (5.18%)
     - Kupiec POF:           LR=0.034 (p=0.8546) -> ACCEPT H0
     - Christoffersen Indep: LR=0.368 (p=0.5440) -> ACCEPT H0
  4. Dynamic GJR-GARCH(1,1) (Asymmetric Leverage):
     - Breaches:             15 / 502 (2.99%)
     - Kupiec POF:           LR=4.968 (p=0.0258) -> REJECT H0
     - Christoffersen Indep: LR=0.542 (p=0.4616) -> ACCEPT H0
  5. Filtered Historical Simulation (FHS / GJR-GARCH Tail):
     - Breaches:             29 / 502 (5.78%)
     - Kupiec POF:           LR=0.609 (p=0.4352) -> ACCEPT H0
     - Christoffersen Indep: LR=0.094 (p=0.7596) -> ACCEPT H0
[+] Saved Backtest Diagnostics plot: /home/beall/projects/var-stress-test/data/plots/var_diagnostics_multi-asset_diverse.png
[+] Saved Monte Carlo Drawdown Surface: /home/beall/projects/var-stress-test/data/plots/stress_matrix_4d_surface.png
